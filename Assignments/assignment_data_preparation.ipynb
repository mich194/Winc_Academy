# %% [markdown]
# <img src="https://static.wincacademy.nl/logos/main-logo.png" height=200px style="height: 200px"/>

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import csv

# %% [markdown]
# # Data Preparation
#
# ## CSV
#
# Let's talk about the messy part of data analytics: preparing data. Before doing the interesting work of data analytics, we need to:
#
# 1. Gather the data.
# 2. Structure the data in such a way that we can work with it in our programs.
# 3. Clean the data, which may include dealing with missing or unreasonable values.
#
# Here we'll assume gathering the data has been done for us. We'll use a dataset provided by the Dutch *Rijksinstituut voor Volksgezondheid en Milieu* (RIVM, translation: National Institute for Health and Environment). It contains COVID-19 numbers per municipality per day. You should place a copy of the data in a file called `covid-data.csv` located in the same folder as this notebook (be it in Google Colab or locally). You can use the URL below to retrieve it.
#
# - Source: Rijksinstituut voor Volksgezondheid en Milieu
# - Data URL: https://data.rivm.nl/covid-19/COVID-19_aantallen_gemeente_per_dag.csv

# %%
data_loc = 'covid-data.csv'
covid_data = open(data_loc).read()

# %% [markdown]
# Let's take a look at what it looks like by printing the first 1000 characters.

# %%
print(covid_data[:1000])
# Out:
# Date_of_report;Date_of_publication;Municipality_code;Municipality_name;Province;Security_region_code;Security_region_name;Municipal_health_service;ROAZ_region;Total_reported;Hospital_admission;Deceased
# 2021-03-24 10:00:00;2020-02-27;GM0014;Groningen;Groningen;VR01;Groningen;GGD Groningen;Acute Zorgnetwerk Noord Nederland;0;0;0
# 2021-03-24 10:00:00;2020-02-27;GM0034;Almere;Flevoland;VR25;Flevoland;GGD Flevoland;SpoedZorgNet;0;0;0
# 2021-03-24 10:00:00;2020-02-27;GM0037;Stadskanaal;Groningen;VR01;Groningen;GGD Groningen;Acute Zorgnetwerk Noord Nederland;0;0;0
# 2021-03-24 10:00:00;2020-02-27;GM0047;Veendam;Groningen;VR01;Groningen;GGD Groningen;Acute Zorgnetwerk Noord Nederland;0;0;0
# 2021-03-24 10:00:00;2020-02-27;GM0050;Zeewolde;Flevoland;VR25;Flevoland;GGD Flevoland;SpoedZorgNet;0;0;0
# 2021-03-24 10:00:00;2020-02-27;GM0059;Achtkarspelen;Frysl̢n;VR02;Frysl̢n;GGD Frysl̢n;Acute Zorgnetwerk Noord Nederland;0;0;0
# 2021-03-24 10:00:00;2020-02-27;GM0060;Ameland;Frysl̢n;VR02;Frysl̢n;GGD Frysl̢n

# %% [markdown]
# That looks pretty chaotic. The data is in a format called `csv`, which is a commonly used format to store and share data.
#
# 1. A `csv` file contains only text.
# 2. The first line a `csv` file lists column names.
# 3. Each line after that is a datapoint with values for those columns in the same order.
#
# Let's look at the first 3 lines instead of the first 1000 characters.

# %%
for line in covid_data.split('\n')[:3]:
    print(line)
# Out:
# Date_of_report;Date_of_publication;Municipality_code;Municipality_name;Province;Security_region_code;Security_region_name;Municipal_health_service;ROAZ_region;Total_reported;Hospital_admission;Deceased
# 2021-03-24 10:00:00;2020-02-27;GM0014;Groningen;Groningen;VR01;Groningen;GGD Groningen;Acute Zorgnetwerk Noord Nederland;0;0;0
# 2021-03-24 10:00:00;2020-02-27;GM0034;Almere;Flevoland;VR25;Flevoland;GGD Flevoland;SpoedZorgNet;0;0;0

# %% [markdown]
# **1. What are the column names for this dataset? List them here.**
#
# *TODO: Your answer here.*
#
# - Date_of_report
# - Date_of_publication
# - Municipality_code
#
# **2. Which character separates the datapoints from each other? Put an `x` in the right box.**
#
# - [x] A linebreak
# - [ ] A tab
# - [ ] A comma
#
# **3. Which character separates the columns within a datapoint from each other?**
#
# semicolon
#
#
# ### Parsing
#
# Let's use this information to read the data into our program in a better way. This is known as [*parsing*](https://en.wikipedia.org/wiki/Parsing). Our goal is to structure the data in such a way that we'll be able to write code like this to make it easier to work with the data:
#
# ```python
# # For some datapoint, show me the municipality that it concerns.
# some_datapoint['Municipality_name']
# ```
#
# By answering the questions above we have all the information we need to organize the internal *data structure* in this way.
#
# - We know what separates datapoints from each other.
# - We know how columns are separated within datapoints.
# - We have the column names for each datapoint.
#
# We can use this information to instruct Python -- the programming language we're using here -- to create a *data structure* that we can use like in the example above. Once completed, we'll have *parsed* the CSV file.
#
# **4. What is parsing in your own words?**
#
# dissecting
#
# **5. Fill in the right column delimiter in the code cell below to complete the code.**

# %%
# TODO: Change PLACEHOLDER to the actual delimiter.
delimiter = ';'
# Make sure the delimiter is surrounded by quotes, for example: delimiter = '<' if the delimiter is <

with open(data_loc) as f:
    csv_reader = csv.DictReader(f, delimiter=delimiter)
    print('Municipality name\tTotal cases reported')
    print('{:=>45}'.format(''))
    data_dicts = list(csv_reader)

for row in data_dicts[:15]:
    print('{:<23} {:<5}'.format(row['Municipality_name'], row['Total_reported']))
# Out:
# Municipality name	Total cases reported
# =============================================
# Groningen               0
# Almere                  0
# Stadskanaal             0
# Veendam                 0
# Zeewolde                0
# Achtkarspelen           0
# Ameland                 0
# Harlingen               0
# Heerenveen              0
# Leeuwarden              0
# Ooststellingwerf        0
# Opsterland              0
# Schiermonnikoog         0
# Smallingerland          0
# Terschelling            0

# %% [markdown]
# Note: Your delimiter was not filled in (correctly) if you got one of these errors:
#
# ```python
# TypeError: "delimiter" must be a 1-character string
# KeyError: 'Municipality_name'
# ```
#
# ## Metadata
#
# Alright, this is much better that looking at raw text, like we did before parsing. We'll get to even better views of the data later. First, let's take a look at some *metadata* -- data about data.
# - The number of datapoints
# - The number of columns
# - The names of the columns (again)
# - The number of missing or empty values
# - The number of unique values in each column

# %%
from collections import defaultdict

print(f'Number of datapoints: {len(data_dicts)}')
print(f'Number of columns: {len(data_dicts[0])}')
print('Column names:')
for k in data_dicts[0].keys():
    print(f'- {k}')
    
unique_vals = [set() for _ in data_dicts[0].keys()]
missing = 0
for datapoint in data_dicts:
    for i, val in enumerate(datapoint.values()):
        unique_vals[i].add(val)
        if val is None or val == '':
            missing += 1
print(f'Missing/empty values: {missing}')

print('Number of unique values:')
for i, k in enumerate(data_dicts[0].keys()):
    print('- {:<25}{:5}'.format(k, len(unique_vals[i])))
# Out:
# Number of datapoints: 148176
# Number of columns: 12
# Column names:
# - Date_of_report
# - Date_of_publication
# - Municipality_code
# - Municipality_name
# - Province
# - Security_region_code
# - Security_region_name
# - Municipal_health_service
# - ROAZ_region
# - Total_reported
# - Hospital_admission
# - Deceased
# Missing/empty values: 22736
# Number of unique values:
# - Date_of_report               1
# - Date_of_publication        392
# - Municipality_code          353
# - Municipality_name          353
# - Province                    12
# - Security_region_code        26
# - Security_region_name        26
# - Municipal_health_service    25
# - ROAZ_region                 12
# - Total_reported             366
# - Hospital_admission          30
# - Deceased                    20

# %% [markdown]
# **6. Note three questions that you have about the data based on this metadata. It might be something like:**
#
# > **"What is the first and last *date of publication* in the dataset?"**
#
# Which date saw the highest numberer of reported cases?
# Which region has the most reported cases on average?
# What is the total average amount of deceased in relation to total hospital admissions?
#
# **7. Note another metadata property that you would like to know about that's not listed here.**
#
# Age, gender, income
#
# ## Working with dates
#
# Looking at the metadata is a good way to get a feel for what a dataset looks like, and what type of questions you can answer with it. Let's use our example question to proceed with data preparation:
#
# > What is the first and last *date of publication* in the dataset?
#
# To answer this question, we can't just assume the first date is at the top and the last date is at the bottom, or vice versa. We need some way to do compare the dates and find out which one is the first and which one is the last. Let's first inspect a few entries in the `Date_of_publication` column to see what they look like.

# %%
print('The current datatype for the Date_of_publication column is:', type(data_dicts[0]['Date_of_publication']))
for row in data_dicts[::int(len(data_dicts) / 20)]:
    print(row['Date_of_publication'])
# Out:
# The current datatype for the Date_of_publication column is: <class 'str'>
# 2020-02-27
# 2020-03-17
# 2020-04-06
# 2020-04-25
# 2020-05-15
# 2020-06-03
# 2020-06-23
# 2020-07-13
# 2020-08-01
# 2020-08-21
# 2020-09-09
# 2020-09-29
# 2020-10-19
# 2020-11-07
# 2020-11-27
# 2020-12-16
# 2021-01-05
# 2021-01-25
# 2021-02-13
# 2021-03-05
# 2021-03-24

# %% [markdown]
# We see that the data type is `str`, which is short for *string*, the programming term for *text*. We can't do any clever comparing with just text. We need to *parse* these dates to be able to make comparisons between them.
#
# Fortunately, the dates are then specified in a certain *date format*. For example, in the Netherlands people often write '24/12/1980' for the 24th day of December in the year 1980. We could specify that format as `DD/MM/YYYY`.
#
# - `DD` stands for 'Two numbers that represent the day'.
# - `MM` stands for 'Two numbers that represent the month'.
# - `YYYY` stands for 'Four numbers that represent the year'.
#
# If they wrote `-` instead of `/`, like so: '24-12-1980', the format would be `DD-MM-YYYY`.
#
# **8. What is the *date format* in the `Date_of_publication` column in our dataset?**
#
# 'YYYY-MM-DD'
#
# **9. Fill in this format in the placeholder in the code block below.**
#
# - **Use `%Y` for `YYYY`.**
# - **Use `%m` for `MM`.**
# - **Use `%d` for `DD`.**
#
# **For example, the Dutch date format ('DD/MM/YYYY' would be `'%d/%m/%Y'`)**

# %%
from datetime import datetime

# TODO: Fill in date format for PLACEHOLDER in the next line.
date_format = '%Y-%m-%d'
# Don't modify anything below this line.

for row in data_dicts:
    formatted_date = datetime.strptime(row['Date_of_publication'], date_format).date()
    row['Date_of_publication'] = formatted_date
    
print('The new datatype for the Date_of_publication column is:', type(data_dicts[0]['Date_of_publication']))
# Out:
# The new datatype for the Date_of_publication column is: <class 'datetime.date'>

# %% [markdown]
# If you get an error like the following, your `date_format` is not correct yet.
#
# ```python
# ValueError: time data '2020-02-27' does not match format 'PLACEHOLDER'
# ```
#
# After filling in `date_format` correctly, you should see a line that confirms that the new datatype for this column is `datetime.date`. Great! Now we can compare the dates in the column and answer our original question:
#
# > What is the first and last *date of publication* in the dataset?
#
# We can now compare the dates with:
#
# - `a > b`: this checks if `a` is *later* than `b`.
# - `a < b`: this checks if `a` is *earlier* than `b`.

# %%
# We make the assumption that the date of publication of the first datapoint is the only date. 
first_date_of_publication = data_dicts[0]['Date_of_publication']
last_date_of_publication = data_dicts[0]['Date_of_publication']
# Then we see if we can find any earlier ones, or later ones.
for row in data_dicts:
    # Check if this date is earlier than the currently known first date of publication
    if row['Date_of_publication'] < first_date_of_publication:
        # If so, this is now the new earliest date.
        first_date_of_publication = row['Date_of_publication']
    # Check if this date is later than the currently known last date of publication
    elif row['Date_of_publication'] > last_date_of_publication:
        # If so, this is now the new latest date.
        last_date_of_publication = row['Date_of_publication']

print(f'The first date of publication is {first_date_of_publication}')
print(f'The last date of publication is {last_date_of_publication}')
print(f'The dataset spans {(last_date_of_publication - first_date_of_publication).days} days')
# Out:
# The first date of publication is 2020-02-27
# The last date of publication is 2021-03-24
# The dataset spans 391 days

# %% [markdown]
# Cool! We now have a better understanding of what the `Date_of_publication` column looks like.
#
# **10. Explain, in your own words, what a string is.**
#
# A sequence of characters
#
# **11. Explain, in your own words, what a date string is.**
#
# A string used for time formatting
#
# **12. Explain, in your own words, why we converted date strings to a `datetime.date` type.**
#
# So it's rendered in a usable format for calculations.
#
#
# ## Working with numbers
#
# We'd like to wrap up this lesson with a nice visualization of how many COVID cases were reported over time in a certain municipality. For that we not only have to work with strings and dates, but also with *numbers*. We can find the right number in the `Total_reported` column, but again, it's not yet in the right format. It's a string, while it needs to be a number.
#
# Let's apply the same strategy that we used with dates before. Note that if you run the cell below multiple times, it will no longer show that the column values used to be a strings -- they were converted the first time.

# %%
print('The current datatype for the Total_reported column is:', type(data_dicts[0]['Total_reported']))
for row in data_dicts:
    row['Total_reported'] = int(row['Total_reported'])
print('The new datatype for the Total_reported column is:', type(data_dicts[0]['Total_reported']))
# Out:
# The current datatype for the Total_reported column is: <class 'str'>
# The new datatype for the Total_reported column is: <class 'int'>

# %% [markdown]
# The new datatype for the `Total_reported` column is `int`, which stands for *integer*. This is the programming term for *whole number*. Bonus: the term for a decimal number is *float*.
#
# **13. Which variable in the code snippet below is an integer? (write an `x` in the right box)**
#
# ```python
# a = 'Hello, world!'
# b = 42
# ```
#
# - [ ] `a`
# - [x] `b`
#
# **14. Which variable in the code snippet below is an integer? (write an `x` in the right box)**
#
# ```python
# a = '42'
# b = 42
# ```
#
# - [ ] `a`
# - [x] `b`
#
# Now that the `Total_reported` column has the correct datatype, let's write a script that tells us the reported number per municipality. For convenience, we first print a list of all the municipalities in the dataset.
#
# **15. Choose one of the municipalities printed in the code block below. Then fill it in (exactly as it was displayed) in the next cell and run it to find the total number of reported cases in that municipality.**

# %%
for m in sorted(unique_vals[3]):
    if m != '':
        print('-', m)
# Out:
# - 's-Gravenhage
# - 's-Hertogenbosch
# - Aa en Hunze
# - Aalsmeer
# - Aalten
# - Achtkarspelen
# - Alblasserdam
# - Albrandswaard
# - Alkmaar
# - Almelo
# - Almere
# - Alphen aan den Rijn
# - Alphen-Chaam
# - Altena
# - Ameland
# - Amersfoort
# - Amstelveen
# - Amsterdam
# - Apeldoorn
# - Arnhem
# - Assen
# - Asten
# - Baarle-Nassau
# - Baarn
# - Barendrecht
# - Barneveld
# - Beek
# - Beekdaelen
# - Beemster
# - Beesel
# - Berg en Dal
# - Bergeijk
# - Bergen (L.)
# - Bergen (NH.)
# - Bergen op Zoom
# - Berkelland
# - Bernheze
# - Best
# - Beuningen
# - Beverwijk
# - Bladel
# - Blaricum
# - Bloemendaal
# - Bodegraven-Reeuwijk
# - Boekel
# - Borger-Odoorn
# - Borne
# - Borsele
# - Boxmeer
# - Boxtel
# - Breda
# - Brielle
# - Bronckhorst
# - Brummen
# - Brunssum
# - Bunnik
# - Bunschoten
# - Buren
# - Capelle aan den IJssel
# - Castricum
# - Coevorden
# - Cranendonck
# - Cuijk
# - Culemborg
# - Dalfsen
# - Dantumadiel
# - De Bilt
# - De Fryske Marren
# - De Ronde Venen
# - De Wolden
# - Delft
# - Den Helder
# - Deurne
# - Deventer
# - Diemen
# - Dinkelland
# - Doesburg
# - Doetinchem
# - Dongen
# - Dordrecht
# - Drechterland
# - Drimmelen
# - Dronten
# - Druten
# - Duiven
# - Echt-Susteren
# - Edam-Volendam
# - Ede
# - Eemnes
# - Eemsdelta
# - Eersel
# - Eijsden-Margraten
# - Eindhoven
# - Elburg
# - Emmen
# - Enkhuizen
# - Enschede
# - Epe
# - Ermelo
# - Etten-Leur
# - Geertruidenberg
# - Geldrop-Mierlo
# - Gemert-Bakel
# - Gennep
# - Gilze en Rijen
# - Goeree-Overflakkee
# - Goes
# - Goirle
# - Gooise Meren
# - Gorinchem
# - Gouda
# - Grave
# - Groningen
# - Gulpen-Wittem
# - Haaksbergen
# - Haarlem
# - Haarlemmermeer
# - Halderberge
# - Hardenberg
# - Harderwijk
# - Hardinxveld-Giessendam
# - Harlingen
# - Hattem
# - Heemskerk
# - Heemstede
# - Heerde
# - Heerenveen
# - Heerhugowaard
# - Heerlen
# - Heeze-Leende
# - Heiloo
# - Hellendoorn
# - Hellevoetsluis
# - Helmond
# - Hendrik-Ido-Ambacht
# - Hengelo (O.)
# - Het Hogeland
# - Heumen
# - Heusden
# - Hillegom
# - Hilvarenbeek
# - Hilversum
# - Hoeksche Waard
# - Hof van Twente
# - Hollands Kroon
# - Hoogeveen
# - Hoorn
# - Horst aan de Maas
# - Houten
# - Huizen
# - Hulst
# - IJsselstein
# - Kaag en Braassem
# - Kampen
# - Kapelle
# - Katwijk
# - Kerkrade
# - Koggenland
# - Krimpen aan den IJssel
# - Krimpenerwaard
# - Laarbeek
# - Landerd
# - Landgraaf
# - Landsmeer
# - Langedijk
# - Lansingerland
# - Laren
# - Leeuwarden
# - Leiden
# - Leiderdorp
# - Leidschendam-Voorburg
# - Lelystad
# - Leudal
# - Leusden
# - Lingewaard
# - Lisse
# - Lochem
# - Loon op Zand
# - Lopik
# - Losser
# - Maasdriel
# - Maasgouw
# - Maassluis
# - Maastricht
# - Medemblik
# - Meerssen
# - Meierijstad
# - Meppel
# - Middelburg
# - Midden-Delfland
# - Midden-Drenthe
# - Midden-Groningen
# - Mill en Sint Hubert
# - Moerdijk
# - Molenlanden
# - Montferland
# - Montfoort
# - Mook en Middelaar
# - Neder-Betuwe
# - Nederweert
# - Nieuwegein
# - Nieuwkoop
# - Nijkerk
# - Nijmegen
# - Nissewaard
# - Noardeast-Frysl̢n
# - Noord-Beveland
# - Noordenveld
# - Noordoostpolder
# - Noordwijk
# - Nuenen, Gerwen en Nederwetten
# - Nunspeet
# - Oegstgeest
# - Oirschot
# - Oisterwijk
# - Oldambt
# - Oldebroek
# - Oldenzaal
# - Olst-Wijhe
# - Ommen
# - Oost Gelre
# - Oosterhout
# - Ooststellingwerf
# - Oostzaan
# - Opmeer
# - Opsterland
# - Oss
# - Oude IJsselstreek
# - Ouder-Amstel
# - Oudewater
# - Overbetuwe
# - Papendrecht
# - Peel en Maas
# - Pekela
# - Pijnacker-Nootdorp
# - Purmerend
# - Putten
# - Raalte
# - Reimerswaal
# - Renkum
# - Renswoude
# - Reusel-De Mierden
# - Rheden
# - Rhenen
# - Ridderkerk
# - Rijssen-Holten
# - Rijswijk
# - Roerdalen
# - Roermond
# - Roosendaal
# - Rotterdam
# - Rozendaal
# - Rucphen
# - Schagen
# - Scherpenzeel
# - Schiedam
# - Schiermonnikoog
# - Schouwen-Duiveland
# - Simpelveld
# - Sint Anthonis
# - Sint-Michielsgestel
# - Sittard-Geleen
# - Sliedrecht
# - Sluis
# - Smallingerland
# - Soest
# - Someren
# - Son en Breugel
# - Stadskanaal
# - Staphorst
# - Stede Broec
# - Steenbergen
# - Steenwijkerland
# - Stein
# - Stichtse Vecht
# - S̼dwest-Frysl̢n
# - Terneuzen
# - Terschelling
# - Texel
# - Teylingen
# - Tholen
# - Tiel
# - Tilburg
# - Tubbergen
# - Twenterand
# - Tynaarlo
# - Tytsjerksteradiel
# - Uden
# - Uitgeest
# - Uithoorn
# - Urk
# - Utrecht
# - Utrechtse Heuvelrug
# - Vaals
# - Valkenburg aan de Geul
# - Valkenswaard
# - Veendam
# - Veenendaal
# - Veere
# - Veldhoven
# - Velsen
# - Venlo
# - Venray
# - Vijfheerenlanden
# - Vlaardingen
# - Vlieland
# - Vlissingen
# - Voerendaal
# - Voorschoten
# - Voorst
# - Vught
# - Waadhoeke
# - Waalre
# - Waalwijk
# - Waddinxveen
# - Wageningen
# - Wassenaar
# - Waterland
# - Weert
# - Weesp
# - West Betuwe
# - West Maas en Waal
# - Westerkwartier
# - Westerveld
# - Westervoort
# - Westerwolde
# - Westland
# - Weststellingwerf
# - Westvoorne
# - Wierden
# - Wijchen
# - Wijdemeren
# - Wijk bij Duurstede
# - Winterswijk
# - Woensdrecht
# - Woerden
# - Wormerland
# - Woudenberg
# - Zaanstad
# - Zaltbommel
# - Zandvoort
# - Zeewolde
# - Zeist
# - Zevenaar
# - Zoetermeer
# - Zoeterwoude
# - Zuidplas
# - Zundert
# - Zutphen
# - Zwartewaterland
# - Zwijndrecht
# - Zwolle

# %%
# TODO: FILL IN THE MUNICIPALITY YOU'RE INTERESTED IN HERE
municipality = 'Rotterdam'
# DON'T MODIFY ANYTHING BELOW THIS LINE

reported = 0
for row in data_dicts:
    if row['Municipality_name'] == municipality:
        reported += row['Total_reported']
print(f'The total number of reported cases in {municipality} is {reported}')
# Out:
# The total number of reported cases in Rotterdam is 55932

# %% [markdown]
# Because we have all the data types in order, we can also easily plot the development of new reported cases for that same municipality.

# %%
new_cases_per_day = defaultdict(int)
for row in data_dicts:
        if row['Municipality_name'] == municipality:
            new_cases_per_day[row['Date_of_publication']] += row['Total_reported']
new_cases_per_day = sorted(new_cases_per_day.items(), key=lambda x: x[0])

fig, ax = plt.subplots(figsize=(16,9))
ax.plot([date for date, _ in new_cases_per_day], [cases for _, cases in new_cases_per_day])
ax.set_xlabel('Date')
ax.set_ylabel('Number of new cases');

# %% [markdown]
# ## Missing Data
#
# Finally, a visualization! Let's tackle one final problem: missing data. When we were looking at the metadata, we found that we have $22736$ missing or empty values. Let's print a few datapoints that contain missing values to see what we're dealing with exactly.

# %%
for i, row in enumerate(data_dicts):
    missing_keys = []
    for key, val in row.items():
        if val == '':
            missing_keys.append(key)
    if missing_keys:
        print(f'Row {i} contains empty values for: {missing_keys}')
# Out:
# Row 353 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 354 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 355 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 356 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 357 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 358 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 359 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 360 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 361 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 362 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 363 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 364 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 365 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 366 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 367 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 368 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 369 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 370 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 371 contains empty values for: ['Municipality_code', 'Municipality_name', 'Security_region_code', 'Security_region_name']
# Row 372 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 373 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 374 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 375 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 376 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 377 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 731 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 732 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 733 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 734 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 735 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 736 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 737 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 738 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 739 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 740 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 741 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 742 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 743 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 744 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 745 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 746 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 747 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 748 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 749 contains empty values for: ['Municipality_code', 'Municipality_name', 'Security_region_code', 'Security_region_name']
# Row 750 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 751 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 752 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 753 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 754 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 755 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 1109 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 1110 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 1111 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 1112 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 1113 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 1114 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 1115 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 1116 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 1117 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 1118 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 1119 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 1120 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 1121 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 1122 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 1123 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 1124 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 1125 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 1126 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 1127 contains empty values for: ['Municipality_code', 'Municipality_name', 'Security_region_code', 'Security_region_name']
# Row 1128 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 1129 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 1130 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 1131 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 1132 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 1133 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 1487 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 1488 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 1489 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 1490 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 1491 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 1492 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 1493 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 1494 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 1495 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 1496 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 1497 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 1498 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 1499 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 1500 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 1501 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 1502 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 1503 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 1504 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 1505 contains empty values for: ['Municipality_code', 'Municipality_name', 'Security_region_code', 'Security_region_name']
# Row 1506 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 1507 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 1508 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 1509 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 1510 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 1511 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 1865 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 1866 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 1867 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 1868 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 1869 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 1870 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 1871 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 1872 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 1873 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 1874 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 1875 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 1876 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 1877 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 1878 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 1879 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 1880 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 1881 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 1882 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 1883 contains empty values for: ['Municipality_code', 'Municipality_name', 'Security_region_code', 'Security_region_name']
# Row 1884 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 1885 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 1886 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 1887 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 1888 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 1889 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 2243 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 2244 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 2245 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 2246 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 2247 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 2248 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 2249 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 2250 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 2251 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 2252 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 2253 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 2254 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 2255 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 2256 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 2257 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 2258 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 2259 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 2260 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 2261 contains empty values for: ['Municipality_code', 'Municipality_name', 'Security_region_code', 'Security_region_name']
# Row 2262 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 2263 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 2264 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 2265 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 2266 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 2267 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 2621 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 2622 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 2623 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 2624 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 2625 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 2626 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 2627 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 2628 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 2629 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 2630 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 2631 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 2632 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 2633 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 2634 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 2635 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 2636 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 2637 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 2638 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 2639 contains empty values for: ['Municipality_code', 'Municipality_name', 'Security_region_code', 'Security_region_name']
# Row 2640 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 2641 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 2642 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 2643 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 2644 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 2645 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 2999 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 3000 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 3001 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 3002 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 3003 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 3004 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 3005 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 3006 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 3007 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 3008 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 3009 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 3010 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 3011 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 3012 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 3013 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 3014 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 3015 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 3016 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 3017 contains empty values for: ['Municipality_code', 'Municipality_name', 'Security_region_code', 'Security_region_name']
# Row 3018 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 3019 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 3020 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 3021 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 3022 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 3023 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 3377 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 3378 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 3379 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 3380 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 3381 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 3382 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 3383 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 3384 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 3385 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 3386 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 3387 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 3388 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 3389 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 3390 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 3391 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 3392 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 3393 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 3394 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 3395 contains empty values for: ['Municipality_code', 'Municipality_name', 'Security_region_code', 'Security_region_name']
# Row 3396 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 3397 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 3398 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 3399 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 3400 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 3401 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 3755 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 3756 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 3757 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 3758 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 3759 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 3760 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 3761 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 3762 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 3763 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 3764 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 3765 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 3766 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 3767 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 3768 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 3769 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 3770 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 3771 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 3772 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 3773 contains empty values for: ['Municipality_code', 'Municipality_name', 'Security_region_code', 'Security_region_name']
# Row 3774 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 3775 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 3776 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 3777 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 3778 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 3779 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 4133 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 4134 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 4135 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 4136 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 4137 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 4138 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 4139 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 4140 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 4141 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 4142 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 4143 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 4144 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 4145 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 4146 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 4147 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 4148 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 4149 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 4150 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 4151 contains empty values for: ['Municipality_code', 'Municipality_name', 'Security_region_code', 'Security_region_name']
# Row 4152 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 4153 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 4154 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 4155 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 4156 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 4157 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 4511 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 4512 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 4513 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 4514 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 4515 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 4516 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 4517 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 4518 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 4519 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 4520 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 4521 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 4522 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 4523 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 4524 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 4525 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 4526 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 4527 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 4528 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 4529 contains empty values for: ['Municipality_code', 'Municipality_name', 'Security_region_code', 'Security_region_name']
# Row 4530 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 4531 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 4532 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 4533 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 4534 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 4535 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 4889 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 4890 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 4891 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 4892 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 4893 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 4894 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 4895 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 4896 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 4897 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 4898 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 4899 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 4900 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 4901 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 4902 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 4903 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 4904 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 4905 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 4906 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 4907 contains empty values for: ['Municipality_code', 'Municipality_name', 'Security_region_code', 'Security_region_name']
# Row 4908 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 4909 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 4910 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 4911 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 4912 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 4913 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 5267 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 5268 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 5269 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 5270 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 5271 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 5272 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 5273 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 5274 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 5275 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 5276 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 5277 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 5278 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 5279 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 5280 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 5281 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 5282 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 5283 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 5284 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 5285 contains empty values for: ['Municipality_code', 'Municipality_name', 'Security_region_code', 'Security_region_name']
# Row 5286 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 5287 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 5288 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 5289 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 5290 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 5291 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 5645 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 5646 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 5647 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 5648 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 5649 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 5650 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 5651 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 5652 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 5653 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 5654 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 5655 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 5656 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 5657 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 5658 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 5659 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 5660 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 5661 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 5662 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 5663 contains empty values for: ['Municipality_code', 'Municipality_name', 'Security_region_code', 'Security_region_name']
# Row 5664 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 5665 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 5666 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 5667 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 5668 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 5669 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 6023 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 6024 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 6025 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 6026 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 6027 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 6028 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 6029 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 6030 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 6031 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 6032 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 6033 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 6034 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 6035 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 6036 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 6037 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 6038 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 6039 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 6040 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 6041 contains empty values for: ['Municipality_code', 'Municipality_name', 'Security_region_code', 'Security_region_name']
# Row 6042 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 6043 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 6044 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 6045 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 6046 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 6047 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 6401 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 6402 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 6403 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 6404 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 6405 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 6406 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 6407 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 6408 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 6409 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 6410 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 6411 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 6412 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 6413 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 6414 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 6415 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 6416 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 6417 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 6418 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 6419 contains empty values for: ['Municipality_code', 'Municipality_name', 'Security_region_code', 'Security_region_name']
# Row 6420 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 6421 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 6422 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 6423 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 6424 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 6425 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 6779 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 6780 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 6781 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 6782 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 6783 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 6784 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 6785 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 6786 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 6787 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 6788 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 6789 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 6790 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 6791 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 6792 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 6793 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 6794 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 6795 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 6796 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 6797 contains empty values for: ['Municipality_code', 'Municipality_name', 'Security_region_code', 'Security_region_name']
# Row 6798 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 6799 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 6800 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 6801 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 6802 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 6803 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 7157 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 7158 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 7159 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 7160 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 7161 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 7162 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 7163 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 7164 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 7165 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 7166 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 7167 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 7168 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 7169 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 7170 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 7171 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 7172 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 7173 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 7174 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 7175 contains empty values for: ['Municipality_code', 'Municipality_name', 'Security_region_code', 'Security_region_name']
# Row 7176 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 7177 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 7178 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 7179 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 7180 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 7181 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 7535 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 7536 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 7537 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 7538 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 7539 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 7540 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 7541 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 7542 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 7543 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 7544 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 7545 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 7546 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 7547 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 7548 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 7549 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 7550 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 7551 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 7552 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 7553 contains empty values for: ['Municipality_code', 'Municipality_name', 'Security_region_code', 'Security_region_name']
# Row 7554 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 7555 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 7556 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 7557 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 7558 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 7559 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 7913 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 7914 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 7915 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 7916 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 7917 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 7918 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 7919 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 7920 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 7921 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 7922 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 7923 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 7924 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 7925 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 7926 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 7927 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 7928 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 7929 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 7930 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 7931 contains empty values for: ['Municipality_code', 'Municipality_name', 'Security_region_code', 'Security_region_name']
# Row 7932 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 7933 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 7934 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 7935 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 7936 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 7937 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 8291 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 8292 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 8293 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 8294 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 8295 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 8296 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 8297 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 8298 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 8299 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 8300 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 8301 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 8302 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 8303 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 8304 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 8305 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 8306 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 8307 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 8308 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 8309 contains empty values for: ['Municipality_code', 'Municipality_name', 'Security_region_code', 'Security_region_name']
# Row 8310 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 8311 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 8312 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 8313 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 8314 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 8315 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 8669 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 8670 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 8671 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 8672 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 8673 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 8674 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 8675 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 8676 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 8677 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 8678 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 8679 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 8680 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 8681 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 8682 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 8683 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 8684 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 8685 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 8686 contains empty values for: ['Municipality_code', 'Municipality_name']
# ...
# Row 145521 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 145522 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 145523 contains empty values for: ['Municipality_code', 'Municipality_name', 'Security_region_code', 'Security_region_name']
# Row 145524 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 145525 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 145526 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 145527 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 145528 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 145529 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 145883 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 145884 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 145885 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 145886 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 145887 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 145888 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 145889 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 145890 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 145891 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 145892 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 145893 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 145894 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 145895 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 145896 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 145897 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 145898 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 145899 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 145900 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 145901 contains empty values for: ['Municipality_code', 'Municipality_name', 'Security_region_code', 'Security_region_name']
# Row 145902 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 145903 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 145904 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 145905 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 145906 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 145907 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 146261 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 146262 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 146263 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 146264 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 146265 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 146266 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 146267 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 146268 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 146269 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 146270 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 146271 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 146272 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 146273 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 146274 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 146275 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 146276 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 146277 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 146278 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 146279 contains empty values for: ['Municipality_code', 'Municipality_name', 'Security_region_code', 'Security_region_name']
# Row 146280 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 146281 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 146282 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 146283 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 146284 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 146285 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 146639 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 146640 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 146641 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 146642 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 146643 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 146644 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 146645 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 146646 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 146647 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 146648 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 146649 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 146650 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 146651 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 146652 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 146653 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 146654 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 146655 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 146656 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 146657 contains empty values for: ['Municipality_code', 'Municipality_name', 'Security_region_code', 'Security_region_name']
# Row 146658 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 146659 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 146660 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 146661 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 146662 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 146663 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 147017 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 147018 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 147019 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 147020 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 147021 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 147022 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 147023 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 147024 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 147025 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 147026 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 147027 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 147028 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 147029 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 147030 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 147031 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 147032 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 147033 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 147034 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 147035 contains empty values for: ['Municipality_code', 'Municipality_name', 'Security_region_code', 'Security_region_name']
# Row 147036 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 147037 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 147038 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 147039 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 147040 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 147041 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 147395 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 147396 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 147397 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 147398 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 147399 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 147400 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 147401 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 147402 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 147403 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 147404 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 147405 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 147406 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 147407 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 147408 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 147409 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 147410 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 147411 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 147412 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 147413 contains empty values for: ['Municipality_code', 'Municipality_name', 'Security_region_code', 'Security_region_name']
# Row 147414 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 147415 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 147416 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 147417 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 147418 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 147419 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 147773 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 147774 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 147775 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 147776 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 147777 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 147778 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 147779 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 147780 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 147781 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 147782 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 147783 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 147784 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 147785 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 147786 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 147787 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 147788 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 147789 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 147790 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 147791 contains empty values for: ['Municipality_code', 'Municipality_name', 'Security_region_code', 'Security_region_name']
# Row 147792 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 147793 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 147794 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 147795 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 147796 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 147797 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 148151 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 148152 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 148153 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 148154 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 148155 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 148156 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 148157 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 148158 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 148159 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 148160 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 148161 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 148162 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 148163 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 148164 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 148165 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 148166 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 148167 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 148168 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 148169 contains empty values for: ['Municipality_code', 'Municipality_name', 'Security_region_code', 'Security_region_name']
# Row 148170 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 148171 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 148172 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 148173 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 148174 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 148175 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']

# %% [markdown]
# **16. What column(s) is/are missing most often?**
#
# Municipality_code and name
#
# Missing data may become a problem if we want to draw comparisons between certain parts of the data. Still, there is no universal and definitive *correct approach* to solving the problem of missing data. In fact, in this case there might actually not be a good way to fill in the missing municipalities here.
#
# For the sake of exercise, we will create a new dataset for your chosen municipality where the `Total_reported` new cases will be replaced with the impossible number `-1` from a number of the dates.
#
# **17. Why is `-1` an impossible number here?**
#
# Reported cases cannot be below null.

# %%
noisy_new_cases_per_day = [(date, cases) if np.random.rand() < 0.8
                           else (date, -1)
                           for date, cases in new_cases_per_day]

fig, ax = plt.subplots(figsize=(16,9))
ax.plot([date for date, _ in new_cases_per_day],
        [cases for _, cases in new_cases_per_day], '.', label='true data')
ax.plot([date for date, _ in noisy_new_cases_per_day],
        [cases for _, cases in noisy_new_cases_per_day],
        label='noisy data')
ax.set_xlabel('Date')
ax.set_ylabel('Number of new cases')
ax.legend();

# %% [markdown]
# This plot is a lot more messy than the clean data plot, in addition to also showing the impossible number `-1`.
#
# **18. What would be a good way to fill in the missing values? You will not need to implement them, so use your imagination.**
#
# Use the average between two datapoints.
#
# Here we'll use the mean of the two surrounding dates' values. For example:
#
# 1. `2020-02-03` is missing
# 2. We take the values from the day before, `2020-02-02`, and the day after, `2020-02-04`. If the data from the day before or after is not available, we use the nearest available datapoint instead.
# 3. We add them up
# 4. Divide them by $2$
# 5. We insert the result as the value for `2020-02-03`.
#
# This is a simple way of doing **interpolation** -- estimating missing values within the range of the data we have. This is the opposite of **extrapolation**, where we have estimate values *outside* of the range of the data we have.
#
# Let's see what the implementation and the result look like.

# %%
interpolated_data = []
max_data_index = len(noisy_new_cases_per_day) - 1
for i, (date, x) in enumerate(noisy_new_cases_per_day):
    # If we have an impossible value
    if x == -1:
        delta_left = 1
        # Scan the left side for values that are not -1
        while noisy_new_cases_per_day[i - delta_left][1] == -1:
            delta_left += 1
            # If we're outside of the data we can't do interpolation. It would be extrapolation.
            if i - delta_left < 0:
                continue
    
        # Scan the right side for values that are not -1
        delta_right = 1
        while noisy_new_cases_per_day[i + delta_right][1] == -1:
            delta_right += 1
            # If we're outside of the data we can't do interpolation. It would be extrapolation.
            if i + delta_right > max_data_index:
                continue
        
        # Finally use the mean of two nearest useful values
        interpolated_value = ((noisy_new_cases_per_day[i - delta_left][1]
                               + noisy_new_cases_per_day[i + delta_right][1])
                              / 2)
        interpolated_data.append((date, interpolated_value))
    else:
        interpolated_data.append((date, x))

fig, ax = plt.subplots(figsize=(16,9))
ax.plot([date for date, _ in new_cases_per_day],
        [cases for _, cases in new_cases_per_day], '.', label='true data')
ax.plot([date for date, _ in interpolated_data],
        [cases for _, cases in interpolated_data],
        label='interpolated data')
ax.plot([date for (date, cases) in noisy_new_cases_per_day if cases == -1],
        [cases for _, cases in noisy_new_cases_per_day if cases == -1], '.',
        label='previously missing data')
ax.set_xlabel('Date')
ax.set_ylabel('Number of new cases')
ax.legend();

# %% [markdown]
# **19. Is this a good way to fill in missing values, in your opinion? Explain.**
#
# It depends on how much data is missing and how consistent the data is.
#
# **20. In which cases will this way of filling in missing values work well, and when will it not work well at all? Give an example for both cases.**
#
# In cases where there is a large quantity of data whereas when there is a small quantity with constant changes such as the stock market it could give a wrong impression since a lot can happen in a short span of time.

# %% [markdown]
# ## Conclusion
#
# Data preparation may not be the most glamorous part of data analytics, but it is quite important. If we do not do it well, every analytics step that comes after will suffer. It is as they say: *garbage in, garbage out*.
#
# It is also good to know that since most data preparation steps are quite general, there are plenty of tools that make doing it a lot easier and faster. All of the above filtering, selecting and interpolating can be done in a few lines of code! But now *you* know how it works under the hood, and why it's so important!
